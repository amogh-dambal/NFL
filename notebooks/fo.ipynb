# %%
import pandas as pd

df = pd.read_csv('../data/fo_qb_2018.csv')
# Out:
# /Users/amogh/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/amogh/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df = df.drop(columns=['Rk.3'])
df.Player = [p[2:] for p in df.Player]

# %%
df
# Out:
#             Player Team    DYAR  Rk     YAR  Rk.1    DVOA  Rk.2     VOA   QBR  \
# 0          Mahomes   KC   2,031   1   1,904     1   39.9%     1   36.7%  81.6
# 1            Brees   NO   1,631   2   1,679     2   36.7%     2   38.1%  80.8
# 2           Rivers  LAC   1,316   3   1,216     4   27.2%     3   24.3%  70.2
# 3             Ryan  ATL   1,232   4   1,352     3   18.2%     4   21.0%  68.2
# 4   Roethlisberger  PIT   1,204   5   1,070     7   14.5%     8   11.7%  71.8
# 5             Goff  LAR   1,114   6   1,110     6   17.0%     5   16.9%  66.4
# 6             Luck  IND   1,070   7   1,152     5   13.3%     9   15.2%  71.7
# 7            Brady   NE   1,034   8   1,051     8   15.4%     7   15.8%  70.6
# 8          Rodgers   GB     817   9     694    10    8.1%    12    5.2%  60.6
# 9           Watson  HOU     737  10     722     9    9.5%    11    9.0%  63.8
# 10          Wilson  SEA     673  11     637    11   11.3%    10   10.2%  65.6
# ...
