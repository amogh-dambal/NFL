# %%
import pandas as pd

df = pd.read_csv('../data/fo_qb_2018.csv')

# %%
df = df.drop(columns=['Rk.3'])
df
# Out:
#               Player Team    DYAR     YAR    DVOA     VOA   QBR  Pass  Yards  \
# 0          P.Mahomes   KC   2,031   1,904   39.9%   36.7%  81.6   607  4,910
# 1            D.Brees   NO   1,631   1,679   36.7%   38.1%  80.8   506  3,854
# 2           P.Rivers  LAC   1,316   1,216   27.2%   24.3%  70.2   540  4,104
# 3             M.Ryan  ATL   1,232   1,352   18.2%   21.0%  68.2   649  4,638
# 4   B.Roethlisberger  PIT   1,204   1,070   14.5%   11.7%  71.8   696  4,944
# 5             J.Goff  LAR   1,114   1,110   17.0%   16.9%  66.4   593  4,450
# 6             A.Luck  IND   1,070   1,152   13.3%   15.2%  71.7   656  4,430
# 7            T.Brady   NE   1,034   1,051   15.4%   15.8%  70.6   589  4,197
# 8          A.Rodgers   GB     817     694    8.1%    5.2%  60.6   644  4,032
# 9           D.Watson  HOU     737     722    9.5%    9.0%  63.8   562  3,779
# 10          R.Wilson  SEA     673     637   11.3%   10.2%  65.6   471  3,090
# ...
