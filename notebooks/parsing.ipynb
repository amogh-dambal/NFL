# %%
import pandas as pd
import numpy
from glob import iglob
import os

# %%
files = [f for f in iglob('../data/**', recursive=True) if os.path.isfile(f) and f.endswith('.csv')]

# %%
dfs = []
for file in files:
    df = pd.read_csv(file)
    dfs.append(df)
df = dfs[0]

# %%
import re
def clean_player(plname):
    return re.sub('\*|\+', '', plname)

# %%
# have to clean up the data first
for df in dfs:
    df.dropna(inplace=True)
    df.drop(df[df.Att < 100].index, inplace=True)
    df.Player = [clean_player(p) for p in df.Player]

# %%
elo_df = pd.read_csv('../data/nfl_elo.csv')

# %%
elo_df.drop(elo_df[(elo_df.season < 2010) | (elo_df.season >= 2019)].index, inplace=True)
elo_df.fillna({'playoff':'x'}, inplace=True)
elo_df
# Out:
#              date  season  neutral playoff team1 team2     elo1_pre  \
# 13871  2010-09-09    2010        0       x    NO   MIN  1635.077000
# 13872  2010-09-12    2010        0       x   SEA    SF  1401.591000
# 13873  2010-09-12    2010        0       x   NYG   CAR  1499.755000
# 13874  2010-09-12    2010        0       x   BUF   MIA  1476.435000
# 13875  2010-09-12    2010        0       x   JAX   DEN  1441.550000
# 13876  2010-09-12    2010        0       x   TEN   OAK  1535.313000
# 13877  2010-09-12    2010        0       x   LAR   ARI  1316.472000
# 13878  2010-09-12    2010        0       x   WSH   DAL  1430.500000
# 13879  2010-09-12    2010        0       x    TB   CLE  1428.762000
# 13880  2010-09-12    2010        0       x   HOU   IND  1546.211000
# 13881  2010-09-12    2010        0       x    NE   CIN  1566.741000
# 13882  2010-09-12    2010        0       x   PHI    GB  1577.744000
# 13883  2010-09-12    2010        0       x   PIT   ATL  1562.390000
# ...
